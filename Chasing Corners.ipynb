# %% [markdown]
# # Particles on an equilateral triangle
# Moving with uniform velocity *v* towards each other at each step.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Simulation parameters
d = 10  # side length of the triangle
v = 1   # speed of the particles
dt = 0.01  # time step
time_steps = 1000 # number of time steps to simulate

# Initial positions of the particles as NumPy arrays
A_pos = np.array([0, 0])
B_pos = np.array([d, 0])
C_pos = np.array([d/2, np.sqrt(3)*d/2])
time = 0

# Store trajectories for plotting
A_trajectory = [A_pos]
B_trajectory = [B_pos]
C_trajectory = [C_pos]

# Function to calculate the next position
def update_position(x1, y1, x2, y2, v, dt):
    # Calculate the direction towards the target
    direction_x = x2 - x1
    direction_y = y2 - y1
    distance = np.sqrt(direction_x**2 + direction_y**2)
    
    # Update position
    new_x = x1 + v * (direction_x / distance) * dt
    new_y = y1 + v * (direction_y / distance) * dt
    return new_x, new_y

# Function to check if the points are approximately equal
def are_points_equal(p1, p2, p3, tolerance):
    # Compare the differences with a tolerance
    return (abs(p1[0] - p2[0]) <= tolerance and abs(p1[1] - p2[1]) <= tolerance and
            abs(p1[0] - p3[0]) <= tolerance and abs(p1[1] - p3[1]) <= tolerance)

# Run the simulation
for _ in range(time_steps) :
    # Update positions based on their respective directions
    A_pos = np.array(update_position(A_pos[0], A_pos[1], B_pos[0], B_pos[1], v, dt))
    B_pos = np.array(update_position(B_pos[0], B_pos[1], C_pos[0], C_pos[1], v, dt))
    C_pos = np.array(update_position(C_pos[0], C_pos[1], A_pos[0], A_pos[1], v, dt))
    
    # Store positions for trajectory
    A_trajectory.append(A_pos)
    B_trajectory.append(B_pos)
    C_trajectory.append(C_pos)

    time = time + dt # update time
    
    if are_points_equal(A_pos, B_pos, C_pos, 1e-2):
        break
        
print("Time taken by the particles to meet:", time)

# Convert to numpy arrays for easier plotting
A_trajectory = np.array(A_trajectory)
B_trajectory = np.array(B_trajectory)
C_trajectory = np.array(C_trajectory)

# Plotting the trajectories
plt.figure(figsize=(7,7))
plt.plot(A_trajectory[:,0], A_trajectory[:,1], label="Particle A", color="r")
plt.plot(B_trajectory[:,0], B_trajectory[:,1], label="Particle B", color="g")
plt.plot(C_trajectory[:,0], C_trajectory[:,1], label="Particle C", color="b")

# Plot the initial triangle
plt.plot([A_trajectory[0,0], B_trajectory[0,0]], [A_trajectory[0,1], B_trajectory[0,1]], 'k--')
plt.plot([B_trajectory[0,0], C_trajectory[0,0]], [B_trajectory[0,1], C_trajectory[0,1]], 'k--')
plt.plot([C_trajectory[0,0], A_trajectory[0,0]], [C_trajectory[0,1], A_trajectory[0,1]], 'k--')

# Plot settings
plt.xlabel("X Position")
plt.ylabel("Y Position")
#plt.title("Trajectories of the Three Particles")
plt.legend(loc='lower right', bbox_to_anchor=(1.3, 0))
plt.grid(True, which='both', linestyle=':', alpha=0.8) 
plt.text(1.3, -0.1, f"Simulation Time: {time:.3f} s", transform=plt.gca().transAxes,
         fontsize=10, verticalalignment='top', horizontalalignment='right')
plt.axis()
plt.savefig('3particle_vel.jpg', format='jpeg', bbox_inches='tight', dpi=1000)
plt.show()
# Out:
# Time taken by the particles to meet: 6.669999999999902

# %% [markdown]
# # Distance Vs Time plot
# Moving with uniform velocity *v* towards each other at each step.

# %%
# Simulation parameters
d = 10  # side length of the triangle
v = 1   # speed of the particles
dt = 0.01  # time step
time_steps = 1000 # number of time steps to simulate

# Initial positions of the particles as NumPy arrays
A_pos = np.array([0, 0])
B_pos = np.array([d, 0])
C_pos = np.array([d/2, np.sqrt(3)*d/2])
time = 0

# Store trajectories for plotting
A_trajectory = [A_pos]
B_trajectory = [B_pos]
C_trajectory = [C_pos]

Position = [0]
Time = [0]

# Function to calculate the next position
def update_position(x1, y1, x2, y2, v, dt):
    # Calculate the direction towards the target
    direction_x = x2 - x1
    direction_y = y2 - y1
    distance = np.sqrt(direction_x**2 + direction_y**2)
    
    # Update position
    new_x = x1 + v * (direction_x / distance) * dt
    new_y = y1 + v * (direction_y / distance) * dt
    return new_x, new_y

# Function to check if the points are approximately equal
def are_points_equal(p1, p2, p3, tolerance):
    # Compare the differences with a tolerance
    return (abs(p1[0] - p2[0]) <= tolerance and abs(p1[1] - p2[1]) <= tolerance and
            abs(p1[0] - p3[0]) <= tolerance and abs(p1[1] - p3[1]) <= tolerance)

# Run the simulation
for _ in range(time_steps) :
    # Update positions based on their respective directions
    A_pos = np.array(update_position(A_pos[0], A_pos[1], B_pos[0], B_pos[1], v, dt))
    B_pos = np.array(update_position(B_pos[0], B_pos[1], C_pos[0], C_pos[1], v, dt))
    C_pos = np.array(update_position(C_pos[0], C_pos[1], A_pos[0], A_pos[1], v, dt))
    
    # Store positions for trajectory
    A_trajectory.append(A_pos)
    B_trajectory.append(B_pos)
    C_trajectory.append(C_pos)

    time = time + dt # update time

    Position.append(np.sqrt((A_pos[0])**2 + (A_pos[1])**2))
    Time.append(time)
    
    #if are_points_equal(A_pos, B_pos, C_pos, 1e-2):
        #break
        
print("Time taken by the particles to meet:", time)

# Convert to numpy arrays for easier plotting
A_trajectory = np.array(A_trajectory)
B_trajectory = np.array(B_trajectory)
C_trajectory = np.array(C_trajectory)

# Plotting the trajectories
plt.figure(figsize=(7,7))
plt.plot(Time, Position, label="Particle A", color="r")
#plt.plot(B_trajectory[:,0], B_trajectory[:,1], label="Particle B", color="g")
#plt.plot(C_trajectory[:,0], C_trajectory[:,1], label="Particle C", color="b")

# Plot the initial triangle
#plt.plot([A_trajectory[0,0], B_trajectory[0,0]], [A_trajectory[0,1], B_trajectory[0,1]], 'k--')
#plt.plot([B_trajectory[0,0], C_trajectory[0,0]], [B_trajectory[0,1], C_trajectory[0,1]], 'k--')
#plt.plot([C_trajectory[0,0], A_trajectory[0,0]], [C_trajectory[0,1], A_trajectory[0,1]], 'k--')

# Plot settings
plt.xlabel("Time")
plt.ylabel("Distance")
#plt.title("Trajectories of the Three Particles")
plt.legend(loc='lower right', bbox_to_anchor=(1.3, 0))
plt.grid(True, which='both', linestyle=':', alpha=0.8) 
plt.text(1.3, -0.1, f"Simulation Time: {time:.3f} s", transform=plt.gca().transAxes,
         fontsize=10, verticalalignment='top', horizontalalignment='right')
plt.axis()
plt.savefig('3particle_dis_time.jpg', format='jpeg', bbox_inches='tight', dpi=1000)
plt.show()
# Out:
# Time taken by the particles to meet: 9.999999999999831

# %% [markdown]
# # Particles on a square
# Moving with uniform velocity *v* towards each other at each step.

# %%
# Simulation parameters
d = 10  # side length of the square
v = 1   # speed of the particles
dt = 0.01  # time step
time_steps = 1000 # number of time steps to simulate

# Initial positions of the particles as NumPy arrays
A_pos = np.array([0, 0])
B_pos = np.array([d, 0])
C_pos = np.array([d, d])
D_pos = np.array([0, d])
time = 0

# Store trajectories for plotting
A_trajectory = [A_pos]
B_trajectory = [B_pos]
C_trajectory = [C_pos]
D_trajectory = [D_pos]


# Function to calculate the next position
def update_position(x1, y1, x2, y2, v, dt):
    # Calculate the direction towards the target
    direction_x = x2 - x1
    direction_y = y2 - y1
    distance = np.sqrt(direction_x**2 + direction_y**2)
    
    # Update position
    new_x = x1 + v * (direction_x / distance) * dt
    new_y = y1 + v * (direction_y / distance) * dt
    return new_x, new_y

# Function to check if the points are approximately equal
def are_points_equal(p1, p2, p3, p4, tolerance):
    # Compare the differences with a tolerance
    return (abs(p1[0] - p2[0]) <= tolerance and abs(p1[1] - p2[1]) <= tolerance and
            abs(p1[0] - p3[0]) <= tolerance and abs(p1[1] - p3[1]) <= tolerance and
            abs(p1[0] - p4[0]) <= tolerance and abs(p1[1] - p4[1]) <= tolerance)
    
# Run the simulation
for _ in range(time_steps) :
    # Update positions based on their respective directions
    A_pos = np.array(update_position(A_pos[0], A_pos[1], B_pos[0], B_pos[1], v, dt))
    B_pos = np.array(update_position(B_pos[0], B_pos[1], C_pos[0], C_pos[1], v, dt))
    C_pos = np.array(update_position(C_pos[0], C_pos[1], D_pos[0], D_pos[1], v, dt))
    D_pos = np.array(update_position(D_pos[0], D_pos[1], A_pos[0], A_pos[1], v, dt))
    
    # Store positions for trajectory
    A_trajectory.append(A_pos)
    B_trajectory.append(B_pos)
    C_trajectory.append(C_pos)
    D_trajectory.append(D_pos)
    

    time = time + dt # update time
    
    if are_points_equal(A_pos, B_pos, C_pos, D_pos, 1e-2):
        break
        
print("Time taken by the particles to meet:", time)

# Convert to numpy arrays for easier plotting
A_trajectory = np.array(A_trajectory)
B_trajectory = np.array(B_trajectory)
C_trajectory = np.array(C_trajectory)
D_trajectory = np.array(D_trajectory)

# Plotting the trajectories
plt.figure(figsize=(7,7))
plt.plot(A_trajectory[:,0], A_trajectory[:,1], label="Particle A", color="r")
plt.plot(B_trajectory[:,0], B_trajectory[:,1], label="Particle B", color="g")
plt.plot(C_trajectory[:,0], C_trajectory[:,1], label="Particle C", color="b")
plt.plot(D_trajectory[:,0], D_trajectory[:,1], label="Particle D", color="m")

# Plot the initial triangle
plt.plot([A_trajectory[0,0], B_trajectory[0,0]], [A_trajectory[0,1], B_trajectory[0,1]], 'k--')
plt.plot([B_trajectory[0,0], C_trajectory[0,0]], [B_trajectory[0,1], C_trajectory[0,1]], 'k--')
plt.plot([C_trajectory[0,0], D_trajectory[0,0]], [C_trajectory[0,1], D_trajectory[0,1]], 'k--')
plt.plot([D_trajectory[0,0], A_trajectory[0,0]], [D_trajectory[0,1], A_trajectory[0,1]], 'k--')


# Plot settings
plt.xlabel("X Position")
plt.ylabel("Y Position")
#plt.title("Trajectories of the Four Particles")
plt.legend(loc='lower right', bbox_to_anchor=(1.3, 0))
plt.grid(True, which='both', linestyle=':', alpha=0.8) 
plt.text(1.3, -0.1, f"Simulation Time: {time:.3f} s", transform=plt.gca().transAxes,
         fontsize=10, verticalalignment='top', horizontalalignment='right')
plt.axis()
plt.savefig('4particle_vel.jpg', format='jpeg', bbox_inches='tight', dpi=1000)
plt.show()
# Out:
# Time taken by the particles to meet: 9.999999999999831

# %% [markdown]
# # Particles on a Pentagon
# Moving with uniform velocity *v* towards each other at each step.

# %%
# Simulation parameters
d = 10  # side length of the pentagon
v = 1   # speed of the particles
dt = 0.001  # time step
time_steps = 20000 # number of time steps to simulate

# Initial positions of the particles as NumPy arrays
A_pos = np.array([0, d])
B_pos = np.array([-0.951 * d, 0.309 * d])
C_pos = np.array([-0.588 * d, -0.809 * d])
D_pos = np.array([0.588 * d, -0.809 * d])
E_pos = np.array([0.951 * d, 0.309 * d])
time = 0

# Store trajectories for plotting
A_trajectory = [A_pos]
B_trajectory = [B_pos]
C_trajectory = [C_pos]
D_trajectory = [D_pos]
E_trajectory = [E_pos]

# Function to calculate the next position
def update_position(x1, y1, x2, y2, v, dt):
    # Calculate the direction towards the target
    direction_x = x2 - x1
    direction_y = y2 - y1
    distance = np.sqrt(direction_x**2 + direction_y**2)
    
    # Update position
    new_x = x1 + v * (direction_x / distance) * dt
    new_y = y1 + v * (direction_y / distance) * dt
    return new_x, new_y

# Function to check if the points are approximately equal
def are_points_equal(p1, p2, p3, p4, p5, tolerance):
    # Compare the differences with a tolerance
    return (abs(p1[0] - p2[0]) <= tolerance and abs(p1[1] - p2[1]) <= tolerance and
            abs(p1[0] - p3[0]) <= tolerance and abs(p1[1] - p3[1]) <= tolerance and
            abs(p1[0] - p4[0]) <= tolerance and abs(p1[1] - p4[1]) <= tolerance and
            abs(p1[0] - p5[0]) <= tolerance and abs(p1[1] - p5[1]) <= tolerance)
    
# Run the simulation
for _ in range(time_steps) :
    # Update positions based on their respective directions
    A_pos = np.array(update_position(A_pos[0], A_pos[1], B_pos[0], B_pos[1], v, dt))
    B_pos = np.array(update_position(B_pos[0], B_pos[1], C_pos[0], C_pos[1], v, dt))
    C_pos = np.array(update_position(C_pos[0], C_pos[1], D_pos[0], D_pos[1], v, dt))
    D_pos = np.array(update_position(D_pos[0], D_pos[1], E_pos[0], E_pos[1], v, dt))
    E_pos = np.array(update_position(E_pos[0], E_pos[1], A_pos[0], A_pos[1], v, dt))
    
    # Store positions for trajectory
    A_trajectory.append(A_pos)
    B_trajectory.append(B_pos)
    C_trajectory.append(C_pos)
    D_trajectory.append(D_pos)
    E_trajectory.append(E_pos)
    

    time = time + dt # update time
    
    if are_points_equal(A_pos, B_pos, C_pos, D_pos, E_pos, 1e-1):
        break
        
print("Time taken by the particles to meet:", time)

# Convert to numpy arrays for easier plotting
A_trajectory = np.array(A_trajectory)
B_trajectory = np.array(B_trajectory)
C_trajectory = np.array(C_trajectory)
D_trajectory = np.array(D_trajectory)
E_trajectory = np.array(E_trajectory)

# Plotting the trajectories
plt.figure(figsize=(7,7))
plt.plot(A_trajectory[:,0], A_trajectory[:,1], label="Particle A", color="r")
plt.plot(B_trajectory[:,0], B_trajectory[:,1], label="Particle B", color="g")
plt.plot(C_trajectory[:,0], C_trajectory[:,1], label="Particle C", color="b")
plt.plot(D_trajectory[:,0], D_trajectory[:,1], label="Particle D", color="m")
plt.plot(E_trajectory[:,0], E_trajectory[:,1], label="Particle E", color="c")

# Plot the initial triangle
plt.plot([A_trajectory[0,0], B_trajectory[0,0]], [A_trajectory[0,1], B_trajectory[0,1]], 'k--')
plt.plot([B_trajectory[0,0], C_trajectory[0,0]], [B_trajectory[0,1], C_trajectory[0,1]], 'k--')
plt.plot([C_trajectory[0,0], D_trajectory[0,0]], [C_trajectory[0,1], D_trajectory[0,1]], 'k--')
plt.plot([D_trajectory[0,0], E_trajectory[0,0]], [D_trajectory[0,1], E_trajectory[0,1]], 'k--')
plt.plot([E_trajectory[0,0], A_trajectory[0,0]], [E_trajectory[0,1], A_trajectory[0,1]], 'k--')


# Plot settings
plt.xlabel("X Position")
plt.ylabel("Y Position")
#plt.title("Trajectories of the Five Particles")
plt.legend(loc='lower right', bbox_to_anchor=(1.3, 0))
plt.grid(True, which='both', linestyle=':', alpha=0.8) 
plt.text(1.3, -0.1, f"Simulation Time: {time:.3f} s", transform=plt.gca().transAxes,
         fontsize=10, verticalalignment='top', horizontalalignment='right')
plt.axis()
plt.savefig('5particle_vel.jpg', format='jpeg', bbox_inches='tight', dpi=1000)
plt.show()
# Out:
# Time taken by the particles to meet: 16.916999999997692

# %% [markdown]
# # Particles on a hexagon
# Moving with uniform velocity *v* towards each other at each step.

# %%
# Simulation parameters
d = 10  # side length of the hexagon
v = 1   # speed of the particles
dt = 0.01  # time step
time_steps = 5000 # number of time steps to simulate

# Initial positions of the particles as NumPy arrays

A_pos = np.array([d, 0])
B_pos = np.array([d/2, np.sqrt(3)*d/2])
C_pos = np.array([-d/2, np.sqrt(3)*d/2])
D_pos = np.array([-d, 0])
E_pos = np.array([-d/2, -np.sqrt(3)*d/2])
F_pos = np.array([d/2, -np.sqrt(3)*d/2])

time = 0

# Store trajectories for plotting
A_trajectory = [A_pos]
B_trajectory = [B_pos]
C_trajectory = [C_pos]
D_trajectory = [D_pos]
E_trajectory = [E_pos]
F_trajectory = [F_pos]


# Function to calculate the next position
def update_position(x1, y1, x2, y2, v, dt):
    # Calculate the direction towards the target
    direction_x = x2 - x1
    direction_y = y2 - y1
    distance = np.sqrt(direction_x**2 + direction_y**2)
    
    # Update position
    new_x = x1 + v * (direction_x / distance) * dt
    new_y = y1 + v * (direction_y / distance) * dt
    return new_x, new_y

# Function to check if the points are approximately equal
def are_points_equal(p1, p2, p3, p4, p5, p6, tolerance):
    # Compare the differences with a tolerance
    return (abs(p1[0] - p2[0]) <= tolerance and abs(p1[1] - p2[1]) <= tolerance and
            abs(p1[0] - p3[0]) <= tolerance and abs(p1[1] - p3[1]) <= tolerance and
            abs(p1[0] - p4[0]) <= tolerance and abs(p1[1] - p4[1]) <= tolerance and
            abs(p1[0] - p5[0]) <= tolerance and abs(p1[1] - p5[1]) <= tolerance and
            abs(p1[0] - p6[0]) <= tolerance and abs(p1[1] - p6[1]) <= tolerance)
    
# Run the simulation
for _ in range(time_steps) :
    # Update positions based on their respective directions
    A_pos = np.array(update_position(A_pos[0], A_pos[1], B_pos[0], B_pos[1], v, dt))
    B_pos = np.array(update_position(B_pos[0], B_pos[1], C_pos[0], C_pos[1], v, dt))
    C_pos = np.array(update_position(C_pos[0], C_pos[1], D_pos[0], D_pos[1], v, dt))
    D_pos = np.array(update_position(D_pos[0], D_pos[1], E_pos[0], E_pos[1], v, dt))
    E_pos = np.array(update_position(E_pos[0], E_pos[1], F_pos[0], F_pos[1], v, dt))
    F_pos = np.array(update_position(F_pos[0], F_pos[1], A_pos[0], A_pos[1], v, dt))
    
    # Store positions for trajectory
    A_trajectory.append(A_pos)
    B_trajectory.append(B_pos)
    C_trajectory.append(C_pos)
    D_trajectory.append(D_pos)
    E_trajectory.append(E_pos)
    F_trajectory.append(F_pos)
    

    time = time + dt # update time
    
    if are_points_equal(A_pos, B_pos, C_pos, D_pos, E_pos, F_pos, 1e-1):
        break
        
print("Time taken by the particles to meet:", time)

# Convert to numpy arrays for easier plotting
A_trajectory = np.array(A_trajectory)
B_trajectory = np.array(B_trajectory)
C_trajectory = np.array(C_trajectory)
D_trajectory = np.array(D_trajectory)
E_trajectory = np.array(E_trajectory)
F_trajectory = np.array(F_trajectory)


# Plotting the trajectories
plt.figure(figsize=(7,7))
plt.plot(A_trajectory[:,0], A_trajectory[:,1], label="Particle A", color="r")
plt.plot(B_trajectory[:,0], B_trajectory[:,1], label="Particle B", color="g")
plt.plot(C_trajectory[:,0], C_trajectory[:,1], label="Particle C", color="b")
plt.plot(D_trajectory[:,0], D_trajectory[:,1], label="Particle D", color="m")
plt.plot(E_trajectory[:,0], E_trajectory[:,1], label="Particle E", color="c")
plt.plot(F_trajectory[:,0], F_trajectory[:,1], label="Particle F", color="y")

# Plot the initial triangle
plt.plot([A_trajectory[0,0], B_trajectory[0,0]], [A_trajectory[0,1], B_trajectory[0,1]], 'k--')
plt.plot([B_trajectory[0,0], C_trajectory[0,0]], [B_trajectory[0,1], C_trajectory[0,1]], 'k--')
plt.plot([C_trajectory[0,0], D_trajectory[0,0]], [C_trajectory[0,1], D_trajectory[0,1]], 'k--')
plt.plot([D_trajectory[0,0], E_trajectory[0,0]], [D_trajectory[0,1], E_trajectory[0,1]], 'k--')
plt.plot([E_trajectory[0,0], F_trajectory[0,0]], [E_trajectory[0,1], F_trajectory[0,1]], 'k--')
plt.plot([F_trajectory[0,0], A_trajectory[0,0]], [F_trajectory[0,1], A_trajectory[0,1]], 'k--')


# Plot settings
plt.xlabel("X Position")
plt.ylabel("Y Position")
#plt.title("Trajectories of the Six Particles")
plt.legend(loc='lower right', bbox_to_anchor=(1.3, 0))
plt.grid(True, which='both', linestyle=':', alpha=0.8) 
plt.text(1.3, -0.1, f"Simulation Time: {time:.3f} s", transform=plt.gca().transAxes,
         fontsize=10, verticalalignment='top', horizontalalignment='right')
plt.axis()
plt.savefig('6particle_vel.jpg', format='jpeg', bbox_inches='tight', dpi=1000)
plt.show()
# Out:
# Time taken by the particles to meet: 19.96000000000032

# %% [markdown]
# # Particles on an equilateral triangle
# Moving with uniform acceleration *a* towards each other at each step (intially at rest).

# %%
# Simulation parameters
d = 0.1  # side length of the triangle
a = 1  # acceleration of the particles
dt = 0.01  # time step
time_steps = 2000 # number of time steps to simulate

# Initial positions of the particles as NumPy arrays
A_pos = np.array([0, 0])
B_pos = np.array([d, 0])
C_pos = np.array([d/2, np.sqrt(3)*d/2])

# Initial positions of the particles as NumPy arrays
A_vel = np.array([0,0])
B_vel = np.array([0,0])
C_vel = np.array([0,0])

time = 0

# Store trajectories for plotting
A_trajectory = [A_pos]
B_trajectory = [B_pos]
C_trajectory = [C_pos]

# Function to calculate the velocity at each step
def update_velocity(x1, y1, x2, y2, vx, vy, a, dt):
    # Calculate the direction towards the target
    direction_x = x2 - x1
    direction_y = y2 - y1
    distance = np.sqrt(direction_x**2 + direction_y**2)
    
    # Update velocity
    new_vx = vx + a * (direction_x / distance) * dt
    new_vy = vy + a * (direction_y / distance) * dt
    return new_vx, new_vy

# Function to calculate the next position
def update_position(x, y, vx, vy, a, dt):
    # Update position
    new_x = x + vx * dt
    new_y = y + vy * dt
    return new_x, new_y

# Function to check if the points are approximately equal
def are_points_equal(p1, p2, p3, tolerance):
    # Compare the differences with a tolerance
    return (abs(p1[0] - p2[0]) <= tolerance and abs(p1[1] - p2[1]) <= tolerance and
            abs(p1[0] - p3[0]) <= tolerance and abs(p1[1] - p3[1]) <= tolerance)


# Run the simulation
for _ in range(time_steps) :

    # Update velocities based on their respective directions
    A_vel = np.array(update_velocity(A_pos[0], A_pos[1], B_pos[0], B_pos[1], A_vel[0], A_vel[1], a, dt))
    B_vel = np.array(update_velocity(B_pos[0], B_pos[1], C_pos[0], C_pos[1], B_vel[0], B_vel[1], a, dt))
    C_vel = np.array(update_velocity(C_pos[0], C_pos[1], A_pos[0], A_pos[1], C_vel[0], C_vel[1], a, dt))
    
    # Update positions based on their respective directions
    A_pos = np.array(update_position(A_pos[0], A_pos[1], A_vel[0], A_vel[1], a, dt))
    B_pos = np.array(update_position(B_pos[0], B_pos[1], B_vel[0], B_vel[1], a, dt))
    C_pos = np.array(update_position(C_pos[0], C_pos[1], C_vel[0], C_vel[1], a, dt))
    
    # Store positions for trajectory
    A_trajectory.append(A_pos)
    B_trajectory.append(B_pos)
    C_trajectory.append(C_pos)

    time = time + dt # update time
    
    if are_points_equal(A_pos, B_pos, C_pos, 1e-2):
        break

    if abs(time - 2.00) <= 1e-1:
        break
        
print("Simulation Time:", time)

# Convert to numpy arrays for easier plotting
A_trajectory = np.array(A_trajectory)
B_trajectory = np.array(B_trajectory)
C_trajectory = np.array(C_trajectory)

# Plotting the trajectories
plt.figure(figsize=(7,7))
plt.plot(A_trajectory[:,0], A_trajectory[:,1], label="Particle A", color="r")
plt.plot(B_trajectory[:,0], B_trajectory[:,1], label="Particle B", color="g")
plt.plot(C_trajectory[:,0], C_trajectory[:,1], label="Particle C", color="b")

# Plot the initial triangle
plt.plot([A_trajectory[0,0], B_trajectory[0,0]], [A_trajectory[0,1], B_trajectory[0,1]], 'k--')
plt.plot([B_trajectory[0,0], C_trajectory[0,0]], [B_trajectory[0,1], C_trajectory[0,1]], 'k--')
plt.plot([C_trajectory[0,0], A_trajectory[0,0]], [C_trajectory[0,1], A_trajectory[0,1]], 'k--')

# Plot settings
plt.xlabel("X Position")
plt.ylabel("Y Position")
#plt.title("Trajectories of the Three Particles")
plt.legend(loc='lower right', bbox_to_anchor=(1.3, 0))
plt.grid(True, which='both', linestyle=':', alpha=0.8) 
plt.text(1.3, -0.1, f"Simulation Time: {time:.3f} s", transform=plt.gca().transAxes,
         fontsize=10, verticalalignment='top', horizontalalignment='right')
plt.axis()
plt.savefig('3particle_acc.jpg', format='jpeg', bbox_inches='tight', dpi=1000)
plt.show()
# Out:
# Simulation Time: 1.9000000000000015

# %% [markdown]
# # Particles on an equilateral triangle (diff initial vel)
# Moving with uniform acceleration *a* towards each other at each step (intially at rest).

# %%
# Simulation parameters
d = 0.1  # side length of the triangle
a = 1  # acceleration of the particles
v = 0.5
dt = 0.01  # time step
time_steps = 200 # number of time steps to simulate

# Initial positions of the particles as NumPy arrays
A_pos = np.array([0, 0])
B_pos = np.array([d, 0])
C_pos = np.array([d/2, np.sqrt(3)*d/2])

centroid = (A_pos + B_pos + C_pos) / 3

def initial_vel(x1, y1, x2, y2, v):
    # Calculate the direction towards the target
    direction_x = x2 - x1
    direction_y = y2 - y1
    distance = np.sqrt(direction_x**2 + direction_y**2)
    
    # Update position
    v_x =  v * (direction_x / distance) 
    v_y =  v * (direction_y / distance) 
    return v_x, v_y

# Initial positions of the particles as NumPy arrays
A_vel = np.array(initial_vel(A_pos[0], A_pos[1], B_pos[0], B_pos[1], v))
B_vel = np.array(initial_vel(B_pos[0], B_pos[1], C_pos[0], C_pos[1], v))
C_vel = np.array(initial_vel(C_pos[0], C_pos[1], A_pos[0], A_pos[1], v))

time = 0

# Store trajectories for plotting
A_trajectory = [A_pos]
B_trajectory = [B_pos]
C_trajectory = [C_pos]

# Function to calculate the velocity at each step
def update_velocity(x1, y1, x2, y2, vx, vy, a, dt):
    # Calculate the direction towards the target
    direction_x = x2 - x1
    direction_y = y2 - y1
    distance = np.sqrt(direction_x**2 + direction_y**2)
    
    # Update velocity
    new_vx = vx + a * (direction_x / distance) * dt
    new_vy = vy + a * (direction_y / distance) * dt
    return new_vx, new_vy

# Function to calculate the next position
def update_position(x, y, vx, vy, a, dt):
    # Update position
    new_x = x + vx * dt
    new_y = y + vy * dt
    return new_x, new_y

# Function to check if the points are approximately equal
def are_points_equal(p1, p2, p3, tolerance):
    # Compare the differences with a tolerance
    return (abs(p1[0] - p2[0]) <= tolerance and abs(p1[1] - p2[1]) <= tolerance and
            abs(p1[0] - p3[0]) <= tolerance and abs(p1[1] - p3[1]) <= tolerance)


# Run the simulation
for _ in range(time_steps) :

    # Update velocities based on their respective directions
    A_vel = np.array(update_velocity(A_pos[0], A_pos[1], B_pos[0], B_pos[1], A_vel[0], A_vel[1], a, dt))
    B_vel = np.array(update_velocity(B_pos[0], B_pos[1], C_pos[0], C_pos[1], B_vel[0], B_vel[1], a, dt))
    C_vel = np.array(update_velocity(C_pos[0], C_pos[1], A_pos[0], A_pos[1], C_vel[0], C_vel[1], a, dt))
    
    # Update positions based on their respective directions
    A_pos = np.array(update_position(A_pos[0], A_pos[1], A_vel[0], A_vel[1], a, dt))
    B_pos = np.array(update_position(B_pos[0], B_pos[1], B_vel[0], B_vel[1], a, dt))
    C_pos = np.array(update_position(C_pos[0], C_pos[1], C_vel[0], C_vel[1], a, dt))
    
    # Store positions for trajectory
    A_trajectory.append(A_pos)
    B_trajectory.append(B_pos)
    C_trajectory.append(C_pos)

    time = time + dt # update time
    
    if are_points_equal(A_pos, B_pos, C_pos, 1e-3):
        break

    if abs(time - 2.00) <= 1e-1:
        break
        
print("Simulation Time:", time)

# Convert to numpy arrays for easier plotting
A_trajectory = np.array(A_trajectory)
B_trajectory = np.array(B_trajectory)
C_trajectory = np.array(C_trajectory)

# Plotting the trajectories
plt.figure(figsize=(7,7))
plt.plot(A_trajectory[:,0], A_trajectory[:,1], label="Particle A", color="r")
plt.plot(B_trajectory[:,0], B_trajectory[:,1], label="Particle B", color="g")
plt.plot(C_trajectory[:,0], C_trajectory[:,1], label="Particle C", color="b")

# Plot the initial triangle
plt.plot([A_trajectory[0,0], B_trajectory[0,0]], [A_trajectory[0,1], B_trajectory[0,1]], 'k--')
plt.plot([B_trajectory[0,0], C_trajectory[0,0]], [B_trajectory[0,1], C_trajectory[0,1]], 'k--')
plt.plot([C_trajectory[0,0], A_trajectory[0,0]], [C_trajectory[0,1], A_trajectory[0,1]], 'k--')

# Plot settings
plt.xlabel("X Position")
plt.ylabel("Y Position")
#plt.title("Trajectories of the Three Particles")
plt.legend(loc='lower right', bbox_to_anchor=(1.3, 0))
plt.grid(True, which='both', linestyle=':', alpha=0.8) 
plt.text(1.3, -0.1, f"Simulation Time: {time:.3f} s", transform=plt.gca().transAxes,
         fontsize=10, verticalalignment='top', horizontalalignment='right')
plt.axis()
plt.savefig('3particle_acc_diff.jpg', format='jpeg', bbox_inches='tight', dpi=1000)
plt.show()
# Out:
# Simulation Time: 1.9000000000000015

# %%
# Simulation parameters
d = 0.1  # side length of the triangle
a = 1  # acceleration of the particles
v = 0.5
dt = 0.01  # time step
time_steps = 200 # number of time steps to simulate

# Initial positions of the particles as NumPy arrays
A_pos = np.array([0, 0])
B_pos = np.array([d, 0])
C_pos = np.array([d/2, np.sqrt(3)*d/2])

centroid = (A_pos + B_pos + C_pos) / 3

def initial_vel(x1, y1, x2, y2, v):
    # Calculate the direction towards the target
    direction_x = x2 - x1
    direction_y = y2 - y1
    distance = np.sqrt(direction_x**2 + direction_y**2)
    
    # Update position
    v_x =  v * (direction_x / distance) 
    v_y =  v * (direction_y / distance) 
    return v_x, v_y

# Initial positions of the particles as NumPy arrays
A_vel = np.array(initial_vel(A_pos[0], A_pos[1], centroid[0], centroid[1], v))
B_vel = np.array(initial_vel(B_pos[0], B_pos[1], centroid[0], centroid[1], v))
C_vel = np.array(initial_vel(C_pos[0], C_pos[1], centroid[0], centroid[1], v))

time = 0

# Store trajectories for plotting
A_trajectory = [A_pos]
B_trajectory = [B_pos]
C_trajectory = [C_pos]

# Function to calculate the velocity at each step
def update_velocity(x1, y1, x2, y2, vx, vy, a, dt):
    # Calculate the direction towards the target
    direction_x = x2 - x1
    direction_y = y2 - y1
    distance = np.sqrt(direction_x**2 + direction_y**2)
    
    # Update velocity
    new_vx = vx + a * (direction_x / distance) * dt
    new_vy = vy + a * (direction_y / distance) * dt
    return new_vx, new_vy

# Function to calculate the next position
def update_position(x, y, vx, vy, a, dt):
    # Update position
    new_x = x + vx * dt
    new_y = y + vy * dt
    return new_x, new_y

# Function to check if the points are approximately equal
def are_points_equal(p1, p2, p3, tolerance):
    # Compare the differences with a tolerance
    return (abs(p1[0] - p2[0]) <= tolerance and abs(p1[1] - p2[1]) <= tolerance and
            abs(p1[0] - p3[0]) <= tolerance and abs(p1[1] - p3[1]) <= tolerance)


# Run the simulation
for _ in range(time_steps) :

    # Update velocities based on their respective directions
    A_vel = np.array(update_velocity(A_pos[0], A_pos[1], B_pos[0], B_pos[1], A_vel[0], A_vel[1], a, dt))
    B_vel = np.array(update_velocity(B_pos[0], B_pos[1], C_pos[0], C_pos[1], B_vel[0], B_vel[1], a, dt))
    C_vel = np.array(update_velocity(C_pos[0], C_pos[1], A_pos[0], A_pos[1], C_vel[0], C_vel[1], a, dt))
    
    # Update positions based on their respective directions
    A_pos = np.array(update_position(A_pos[0], A_pos[1], A_vel[0], A_vel[1], a, dt))
    B_pos = np.array(update_position(B_pos[0], B_pos[1], B_vel[0], B_vel[1], a, dt))
    C_pos = np.array(update_position(C_pos[0], C_pos[1], C_vel[0], C_vel[1], a, dt))
    
    # Store positions for trajectory
    A_trajectory.append(A_pos)
    B_trajectory.append(B_pos)
    C_trajectory.append(C_pos)

    time = time + dt # update time
    
    if are_points_equal(A_pos, B_pos, C_pos, 1e-3):
        break

    if abs(time - 2.00) <= 1e-1:
        break
        
print("Simulation Time:", time)

# Convert to numpy arrays for easier plotting
A_trajectory = np.array(A_trajectory)
B_trajectory = np.array(B_trajectory)
C_trajectory = np.array(C_trajectory)

# Plotting the trajectories
plt.figure(figsize=(7,7))
plt.plot(A_trajectory[:,0], A_trajectory[:,1], label="Particle A", color="r")
plt.plot(B_trajectory[:,0], B_trajectory[:,1], label="Particle B", color="g")
plt.plot(C_trajectory[:,0], C_trajectory[:,1], label="Particle C", color="b")

# Plot the initial triangle
plt.plot([A_trajectory[0,0], B_trajectory[0,0]], [A_trajectory[0,1], B_trajectory[0,1]], 'k--')
plt.plot([B_trajectory[0,0], C_trajectory[0,0]], [B_trajectory[0,1], C_trajectory[0,1]], 'k--')
plt.plot([C_trajectory[0,0], A_trajectory[0,0]], [C_trajectory[0,1], A_trajectory[0,1]], 'k--')

# Plot settings
plt.xlabel("X Position")
plt.ylabel("Y Position")
#plt.title("Trajectories of the Three Particles")
plt.legend(loc='lower right', bbox_to_anchor=(1.3, 0))
plt.grid(True, which='both', linestyle=':', alpha=0.8) 
plt.text(1.3, -0.1, f"Simulation Time: {time:.3f} s", transform=plt.gca().transAxes,
         fontsize=10, verticalalignment='top', horizontalalignment='right')
plt.axis()
plt.savefig('3particle_acc_cent.jpg', format='jpeg', bbox_inches='tight', dpi=1000)
plt.show()
# Out:
# Simulation Time: 1.9000000000000015

# %% [markdown]
# # Particles on a Square
# Moving with uniform acceleration *a* towards each other at each step (intially at rest).

# %%
# Simulation parameters
d = 0.1  # side length of the square
a = 1  # acceleration of the particles
dt = 0.01  # time step
time_steps = 2000 # number of time steps to simulate

# Initial positions of the particles as NumPy arrays
A_pos = np.array([0, 0])
B_pos = np.array([d, 0])
C_pos = np.array([d, d])
D_pos = np.array([0, d])
time = 0

# Initial positions of the particles as NumPy arrays
A_vel = np.array([0,0])
B_vel = np.array([0,0])
C_vel = np.array([0,0])
D_vel = np.array([0,0])

# Store trajectories for plotting
A_trajectory = [A_pos]
B_trajectory = [B_pos]
C_trajectory = [C_pos]
D_trajectory = [D_pos]


# Function to calculate the velocity at each step
def update_velocity(x1, y1, x2, y2, vx, vy, a, dt):
    # Calculate the direction towards the target
    direction_x = x2 - x1
    direction_y = y2 - y1
    distance = np.sqrt(direction_x**2 + direction_y**2)
    
    # Update velocity
    new_vx = vx + a * (direction_x / distance) * dt
    new_vy = vy + a * (direction_y / distance) * dt
    return new_vx, new_vy

# Function to calculate the next position
def update_position(x, y, vx, vy, a, dt):
    # Update position
    new_x = x + vx * dt
    new_y = y + vy * dt
    return new_x, new_y

# Function to check if the points are approximately equal
def are_points_equal(p1, p2, p3, p4, tolerance):
    # Compare the differences with a tolerance
    return (abs(p1[0] - p2[0]) <= tolerance and abs(p1[1] - p2[1]) <= tolerance and
            abs(p1[0] - p3[0]) <= tolerance and abs(p1[1] - p3[1]) <= tolerance and
            abs(p1[0] - p4[0]) <= tolerance and abs(p1[1] - p4[1]) <= tolerance)


# Run the simulation
for _ in range(time_steps) :

    # Update velocities based on their respective directions
    A_vel = np.array(update_velocity(A_pos[0], A_pos[1], B_pos[0], B_pos[1], A_vel[0], A_vel[1], a, dt))
    B_vel = np.array(update_velocity(B_pos[0], B_pos[1], C_pos[0], C_pos[1], B_vel[0], B_vel[1], a, dt))
    C_vel = np.array(update_velocity(C_pos[0], C_pos[1], D_pos[0], D_pos[1], C_vel[0], C_vel[1], a, dt))
    D_vel = np.array(update_velocity(D_pos[0], D_pos[1], A_pos[0], A_pos[1], D_vel[0], D_vel[1], a, dt))
    
    # Update positions based on their respective directions
    A_pos = np.array(update_position(A_pos[0], A_pos[1], A_vel[0], A_vel[1], a, dt))
    B_pos = np.array(update_position(B_pos[0], B_pos[1], B_vel[0], B_vel[1], a, dt))
    C_pos = np.array(update_position(C_pos[0], C_pos[1], C_vel[0], C_vel[1], a, dt))
    D_pos = np.array(update_position(D_pos[0], D_pos[1], D_vel[0], D_vel[1], a, dt))
    
    # Store positions for trajectory
    A_trajectory.append(A_pos)
    B_trajectory.append(B_pos)
    C_trajectory.append(C_pos)
    D_trajectory.append(D_pos)
    

    time = time + dt # update time
    
    if are_points_equal(A_pos, B_pos, C_pos, D_pos, 1e-2):
        break

    if abs(time - 2.00) <= 1e-1:
        break

        
print("Simulation Time:", time)

# Convert to numpy arrays for easier plotting
A_trajectory = np.array(A_trajectory)
B_trajectory = np.array(B_trajectory)
C_trajectory = np.array(C_trajectory)
D_trajectory = np.array(D_trajectory)


# Plotting the trajectories
plt.figure(figsize=(7,7))
plt.plot(A_trajectory[:,0], A_trajectory[:,1], label="Particle A", color="r")
plt.plot(B_trajectory[:,0], B_trajectory[:,1], label="Particle B", color="g")
plt.plot(C_trajectory[:,0], C_trajectory[:,1], label="Particle C", color="b")
plt.plot(D_trajectory[:,0], D_trajectory[:,1], label="Particle D", color="m")

# Plot the initial triangle
plt.plot([A_trajectory[0,0], B_trajectory[0,0]], [A_trajectory[0,1], B_trajectory[0,1]], 'k--')
plt.plot([B_trajectory[0,0], C_trajectory[0,0]], [B_trajectory[0,1], C_trajectory[0,1]], 'k--')
plt.plot([C_trajectory[0,0], D_trajectory[0,0]], [C_trajectory[0,1], D_trajectory[0,1]], 'k--')
plt.plot([D_trajectory[0,0], A_trajectory[0,0]], [D_trajectory[0,1], A_trajectory[0,1]], 'k--')

# Plot settings
plt.xlabel("X Position")
plt.ylabel("Y Position")
#plt.title("Trajectories of the Four Particles")
plt.legend(loc='lower right', bbox_to_anchor=(1.3, 0))
plt.grid(True, which='both', linestyle=':', alpha=0.8) 
plt.text(1.3, -0.1, f"Simulation Time: {time:.3f} s", transform=plt.gca().transAxes,
         fontsize=10, verticalalignment='top', horizontalalignment='right')
plt.axis()
plt.savefig('4particle_acc.jpg', format='jpeg', bbox_inches='tight', dpi=1000)
plt.show()
# Out:
# Simulation Time: 1.9000000000000015

# %% [markdown]
# # Particles on a Pentagon
# Moving with uniform acceleration *a* towards each other at each step (intially at rest).

# %%
# Simulation parameters
d = 0.1  # side length of the pentagon
a = 1  # acceleration of the particles
dt = 0.01  # time step
time_steps = 2000 # number of time steps to simulate

# Initial positions of the particles as NumPy arrays
A_pos = np.array([0, d])
B_pos = np.array([-0.951 * d, 0.309 * d])
C_pos = np.array([-0.588 * d, -0.809 * d])
D_pos = np.array([0.588 * d, -0.809 * d])
E_pos = np.array([0.951 * d, 0.309 * d])
time = 0

# Initial positions of the particles as NumPy arrays
A_vel = np.array([0,0])
B_vel = np.array([0,0])
C_vel = np.array([0,0])
D_vel = np.array([0,0])
E_vel = np.array([0,0])

# Store trajectories for plotting
A_trajectory = [A_pos]
B_trajectory = [B_pos]
C_trajectory = [C_pos]
D_trajectory = [D_pos]
E_trajectory = [E_pos]



# Function to calculate the velocity at each step
def update_velocity(x1, y1, x2, y2, vx, vy, a, dt):
    # Calculate the direction towards the target
    direction_x = x2 - x1
    direction_y = y2 - y1
    distance = np.sqrt(direction_x**2 + direction_y**2)
    
    # Update velocity
    new_vx = vx + a * (direction_x / distance) * dt
    new_vy = vy + a * (direction_y / distance) * dt
    return new_vx, new_vy

# Function to calculate the next position
def update_position(x, y, vx, vy, a, dt):
    # Update position
    new_x = x + vx * dt
    new_y = y + vy * dt
    return new_x, new_y

# Function to check if the points are approximately equal
def are_points_equal(p1, p2, p3, p4, p5, tolerance):
    # Compare the differences with a tolerance
    return (abs(p1[0] - p2[0]) <= tolerance and abs(p1[1] - p2[1]) <= tolerance and
            abs(p1[0] - p3[0]) <= tolerance and abs(p1[1] - p3[1]) <= tolerance and
            abs(p1[0] - p4[0]) <= tolerance and abs(p1[1] - p4[1]) <= tolerance and
            abs(p1[0] - p5[0]) <= tolerance and abs(p1[1] - p5[1]) <= tolerance)


# Run the simulation
for _ in range(time_steps) :

    # Update velocities based on their respective directions
    A_vel = np.array(update_velocity(A_pos[0], A_pos[1], B_pos[0], B_pos[1], A_vel[0], A_vel[1], a, dt))
    B_vel = np.array(update_velocity(B_pos[0], B_pos[1], C_pos[0], C_pos[1], B_vel[0], B_vel[1], a, dt))
    C_vel = np.array(update_velocity(C_pos[0], C_pos[1], D_pos[0], D_pos[1], C_vel[0], C_vel[1], a, dt))
    D_vel = np.array(update_velocity(D_pos[0], D_pos[1], E_pos[0], E_pos[1], D_vel[0], D_vel[1], a, dt))
    E_vel = np.array(update_velocity(E_pos[0], E_pos[1], A_pos[0], A_pos[1], E_vel[0], E_vel[1], a, dt))
    
    # Update positions based on their respective directions
    A_pos = np.array(update_position(A_pos[0], A_pos[1], A_vel[0], A_vel[1], a, dt))
    B_pos = np.array(update_position(B_pos[0], B_pos[1], B_vel[0], B_vel[1], a, dt))
    C_pos = np.array(update_position(C_pos[0], C_pos[1], C_vel[0], C_vel[1], a, dt))
    D_pos = np.array(update_position(D_pos[0], D_pos[1], D_vel[0], D_vel[1], a, dt))
    E_pos = np.array(update_position(E_pos[0], E_pos[1], E_vel[0], E_vel[1], a, dt))
    
    # Store positions for trajectory
    A_trajectory.append(A_pos)
    B_trajectory.append(B_pos)
    C_trajectory.append(C_pos)
    D_trajectory.append(D_pos)
    E_trajectory.append(E_pos)
    

    time = time + dt # update time
    
    if are_points_equal(A_pos, B_pos, C_pos, D_pos, E_pos, 1e-1):
        break

    if abs(time - 2.00) <= 1e-1:
        break

        
print("Simulation Time:", time)

# Convert to numpy arrays for easier plotting
A_trajectory = np.array(A_trajectory)
B_trajectory = np.array(B_trajectory)
C_trajectory = np.array(C_trajectory)
D_trajectory = np.array(D_trajectory)
E_trajectory = np.array(E_trajectory)


# Plotting the trajectories
plt.figure(figsize=(7,7))
plt.plot(A_trajectory[:,0], A_trajectory[:,1], label="Particle A", color="r")
plt.plot(B_trajectory[:,0], B_trajectory[:,1], label="Particle B", color="g")
plt.plot(C_trajectory[:,0], C_trajectory[:,1], label="Particle C", color="b")
plt.plot(D_trajectory[:,0], D_trajectory[:,1], label="Particle D", color="m")
plt.plot(E_trajectory[:,0], E_trajectory[:,1], label="Particle E", color="c")

# Plot the initial triangle
plt.plot([A_trajectory[0,0], B_trajectory[0,0]], [A_trajectory[0,1], B_trajectory[0,1]], 'k--')
plt.plot([B_trajectory[0,0], C_trajectory[0,0]], [B_trajectory[0,1], C_trajectory[0,1]], 'k--')
plt.plot([C_trajectory[0,0], D_trajectory[0,0]], [C_trajectory[0,1], D_trajectory[0,1]], 'k--')
plt.plot([D_trajectory[0,0], E_trajectory[0,0]], [D_trajectory[0,1], E_trajectory[0,1]], 'k--')
plt.plot([E_trajectory[0,0], A_trajectory[0,0]], [E_trajectory[0,1], A_trajectory[0,1]], 'k--')

# Plot settings
plt.xlabel("X Position")
plt.ylabel("Y Position")
#plt.title("Trajectories of the Five Particles")
plt.legend(loc='lower right', bbox_to_anchor=(1.3, 0))
plt.grid(True, which='both', linestyle=':', alpha=0.8) 
plt.text(1.3, -0.1, f"Simulation Time: {time:.3f} s", transform=plt.gca().transAxes,
         fontsize=10, verticalalignment='top', horizontalalignment='right')
plt.axis()
plt.savefig('5particle_acc.jpg', format='jpeg', bbox_inches='tight', dpi=1000)
plt.show()
# Out:
# Simulation Time: 1.9000000000000015

# %% [markdown]
# # Particles on a Hexagon
# Moving with uniform acceleration *a* towards each other at each step (intially at rest).

# %%
# Simulation parameters
d = 0.1  # side length of the hexagon
a = 1  # acceleration of the particles
dt = 0.01  # time step
time_steps = 1500 # number of time steps to simulate

# Initial positions of the particles as NumPy arrays
A_pos = np.array([d, 0])
B_pos = np.array([d/2, np.sqrt(3)*d/2])
C_pos = np.array([-d/2, np.sqrt(3)*d/2])
D_pos = np.array([-d, 0])
E_pos = np.array([-d/2, -np.sqrt(3)*d/2])
F_pos = np.array([d/2, -np.sqrt(3)*d/2])

time = 0

# Initial positions of the particles as NumPy arrays
A_vel = np.array([0,0])
B_vel = np.array([0,0])
C_vel = np.array([0,0])
D_vel = np.array([0,0])
E_vel = np.array([0,0])
F_vel = np.array([0,0])

# Store trajectories for plotting
A_trajectory = [A_pos]
B_trajectory = [B_pos]
C_trajectory = [C_pos]
D_trajectory = [D_pos]
E_trajectory = [E_pos]
F_trajectory = [F_pos]


# Function to calculate the velocity at each step
def update_velocity(x1, y1, x2, y2, vx, vy, a, dt):
    # Calculate the direction towards the target
    direction_x = x2 - x1
    direction_y = y2 - y1
    distance = np.sqrt(direction_x**2 + direction_y**2)
    
    # Update velocity
    new_vx = vx + a * (direction_x / distance) * dt
    new_vy = vy + a * (direction_y / distance) * dt
    return new_vx, new_vy

# Function to calculate the next position
def update_position(x, y, vx, vy, a, dt):
    # Update position
    new_x = x + vx * dt
    new_y = y + vy * dt
    return new_x, new_y

# Function to check if the points are approximately equal
def are_points_equal(p1, p2, p3, p4, p5, p6, tolerance):
    # Compare the differences with a tolerance
    return (abs(p1[0] - p2[0]) <= tolerance and abs(p1[1] - p2[1]) <= tolerance and
            abs(p1[0] - p3[0]) <= tolerance and abs(p1[1] - p3[1]) <= tolerance and
            abs(p1[0] - p4[0]) <= tolerance and abs(p1[1] - p4[1]) <= tolerance and
            abs(p1[0] - p5[0]) <= tolerance and abs(p1[1] - p5[1]) <= tolerance and
            abs(p1[0] - p6[0]) <= tolerance and abs(p1[1] - p6[1]) <= tolerance)


# Run the simulation
for _ in range(time_steps) :

    # Update velocities based on their respective directions
    A_vel = np.array(update_velocity(A_pos[0], A_pos[1], B_pos[0], B_pos[1], A_vel[0], A_vel[1], a, dt))
    B_vel = np.array(update_velocity(B_pos[0], B_pos[1], C_pos[0], C_pos[1], B_vel[0], B_vel[1], a, dt))
    C_vel = np.array(update_velocity(C_pos[0], C_pos[1], D_pos[0], D_pos[1], C_vel[0], C_vel[1], a, dt))
    D_vel = np.array(update_velocity(D_pos[0], D_pos[1], E_pos[0], E_pos[1], D_vel[0], D_vel[1], a, dt))
    E_vel = np.array(update_velocity(E_pos[0], E_pos[1], F_pos[0], F_pos[1], E_vel[0], E_vel[1], a, dt))
    F_vel = np.array(update_velocity(F_pos[0], F_pos[1], A_pos[0], A_pos[1], F_vel[0], F_vel[1], a, dt))
    
    # Update positions based on their respective directions
    A_pos = np.array(update_position(A_pos[0], A_pos[1], A_vel[0], A_vel[1], a, dt))
    B_pos = np.array(update_position(B_pos[0], B_pos[1], B_vel[0], B_vel[1], a, dt))
    C_pos = np.array(update_position(C_pos[0], C_pos[1], C_vel[0], C_vel[1], a, dt))
    D_pos = np.array(update_position(D_pos[0], D_pos[1], D_vel[0], D_vel[1], a, dt))
    E_pos = np.array(update_position(E_pos[0], E_pos[1], E_vel[0], E_vel[1], a, dt))
    F_pos = np.array(update_position(F_pos[0], F_pos[1], F_vel[0], F_vel[1], a, dt))
    
    # Store positions for trajectory
    A_trajectory.append(A_pos)
    B_trajectory.append(B_pos)
    C_trajectory.append(C_pos)
    D_trajectory.append(D_pos)
    E_trajectory.append(E_pos)
    F_trajectory.append(F_pos)
    

    time = time + dt # update time
    
    if are_points_equal(A_pos, B_pos, C_pos, D_pos, E_pos, F_pos, 1e-2):
        break

    if abs(time - 2.00) <= 1e-1:
        break

        
print("Simulation Time:", time)

# Convert to numpy arrays for easier plotting
A_trajectory = np.array(A_trajectory)
B_trajectory = np.array(B_trajectory)
C_trajectory = np.array(C_trajectory)
D_trajectory = np.array(D_trajectory)
E_trajectory = np.array(E_trajectory)
F_trajectory = np.array(F_trajectory)


# Plotting the trajectories
plt.figure(figsize=(7,7))
plt.plot(A_trajectory[:,0], A_trajectory[:,1], label="Particle A", color="r")
plt.plot(B_trajectory[:,0], B_trajectory[:,1], label="Particle B", color="g")
plt.plot(C_trajectory[:,0], C_trajectory[:,1], label="Particle C", color="b")
plt.plot(D_trajectory[:,0], D_trajectory[:,1], label="Particle D", color="m")
plt.plot(E_trajectory[:,0], E_trajectory[:,1], label="Particle E", color="c")
plt.plot(F_trajectory[:,0], F_trajectory[:,1], label="Particle F", color="y")

# Plot the initial triangle
plt.plot([A_trajectory[0,0], B_trajectory[0,0]], [A_trajectory[0,1], B_trajectory[0,1]], 'k--')
plt.plot([B_trajectory[0,0], C_trajectory[0,0]], [B_trajectory[0,1], C_trajectory[0,1]], 'k--')
plt.plot([C_trajectory[0,0], D_trajectory[0,0]], [C_trajectory[0,1], D_trajectory[0,1]], 'k--')
plt.plot([D_trajectory[0,0], E_trajectory[0,0]], [D_trajectory[0,1], E_trajectory[0,1]], 'k--')
plt.plot([E_trajectory[0,0], F_trajectory[0,0]], [E_trajectory[0,1], F_trajectory[0,1]], 'k--')
plt.plot([F_trajectory[0,0], A_trajectory[0,0]], [F_trajectory[0,1], A_trajectory[0,1]], 'k--')

# Plot settings
plt.xlabel("X Position")
plt.ylabel("Y Position")
#plt.title("Trajectories of the Six Particles")
plt.legend(loc='lower right', bbox_to_anchor=(1.3, 0))
plt.grid(True, which='both', linestyle=':', alpha=0.8)
plt.text(1.3, -0.1, f"Simulation Time: {time:.3f} s", transform=plt.gca().transAxes,
         fontsize=10, verticalalignment='top', horizontalalignment='right')
plt.axis()
plt.savefig('6particle_acc.jpg', format='jpeg', bbox_inches='tight', dpi=1000)
plt.show()
# Out:
# Simulation Time: 1.9000000000000015

# %% [markdown]
# # Particles on an equilateral triangle (Velocity time plot)
# Moving with uniform acceleration *a* towards each other at each step (intially at rest), for a limited time.

# %%
# Simulation parameters
d = 10  # side length of the triangle
a = 1  # acceleration of the particles
dt = 0.01  # time step
time_steps = 2000 # number of time steps to simulate

# Initial positions of the particles as NumPy arrays
A_pos = np.array([0, 0])
B_pos = np.array([d, 0])
C_pos = np.array([d/2, np.sqrt(3)*d/2])

# Initial positions of the particles as NumPy arrays
A_vel = np.array([0,0])
B_vel = np.array([0,0])
C_vel = np.array([0,0])

time = 0

# Store trajectories for plotting
A_trajectory = [A_pos]
B_trajectory = [B_pos]
C_trajectory = [C_pos]

A_velocity = [A_vel]
B_velocity = [B_vel]
C_velocity = [C_vel]

Time = [0]
Velocity = [0]

# Function to calculate the velocity at each step
def update_velocity(x1, y1, x2, y2, vx, vy, a, dt):
    # Calculate the direction towards the target
    direction_x = x2 - x1
    direction_y = y2 - y1
    distance = np.sqrt(direction_x**2 + direction_y**2)
    
    # Update velocity
    new_vx = vx + (a * (direction_x / distance) * dt)
    new_vy = vy + (a * (direction_y / distance) * dt)
    return new_vx, new_vy

# Function to calculate the next position
def update_position(x, y, vx, vy, a, time):
    # Update position
    new_x = x + (vx * dt)  
    new_y = y + (vy * dt) 
    return new_x, new_y

# Function to check if the points are approximately equal
def are_points_equal(p1, p2, p3, tolerance):
    # Compare the differences with a tolerance
    return (abs(p1[0] - p2[0]) <= tolerance and abs(p1[1] - p2[1]) <= tolerance and
            abs(p1[0] - p3[0]) <= tolerance and abs(p1[1] - p3[1]) <= tolerance)


# Run the simulation
for _ in range(time_steps) :

    # Update velocities based on their respective directions
    A_vel = np.array(update_velocity(A_pos[0], A_pos[1], B_pos[0], B_pos[1], A_vel[0], A_vel[1], a, dt))
    B_vel = np.array(update_velocity(B_pos[0], B_pos[1], C_pos[0], C_pos[1], B_vel[0], B_vel[1], a, dt))
    C_vel = np.array(update_velocity(C_pos[0], C_pos[1], A_pos[0], A_pos[1], C_vel[0], C_vel[1], a, dt))

    # Update positions based on their respective directions
    A_pos = np.array(update_position(A_pos[0], A_pos[1], A_vel[0], A_vel[1], a, time))
    B_pos = np.array(update_position(B_pos[0], B_pos[1], B_vel[0], B_vel[1], a, time))
    C_pos = np.array(update_position(C_pos[0], C_pos[1], C_vel[0], C_vel[1], a, time))
    
    
    # Store positions for trajectory
    A_trajectory.append(A_pos)
    B_trajectory.append(B_pos)
    C_trajectory.append(C_pos)

    A_velocity.append(A_vel)
    B_velocity.append(B_vel)
    C_velocity.append(C_vel)

    time = time + dt # update time

    if abs(time - 2.00) <= 1e-1:
        break
        
    Time.append(time)
    Velocity.append(np.sqrt((A_vel[0])**2 + (A_vel[1])**2))
    
    #if are_points_equal(A_pos, B_pos, C_pos, 1e-2):
        #break

    #if abs(time - np.sqrt((4*d)/(3*a))) <= 1e-2:
        #break
        
print("Simulation Time:", time)

# Convert to numpy arrays for easier plotting
A_trajectory = np.array(A_trajectory)
B_trajectory = np.array(B_trajectory)
C_trajectory = np.array(C_trajectory)

A_velocity = np.array(A_velocity)
B_velocity = np.array(B_velocity)
C_velocity = np.array(C_velocity)

# Plotting the trajectories
plt.figure(figsize=(7,7))
#plt.plot(A_trajectory[:,0], A_trajectory[:,1], label="Particle A", color="r")
#plt.plot(B_trajectory[:,0], B_trajectory[:,1], label="Particle B", color="g")
#plt.plot(C_trajectory[:,0], C_trajectory[:,1], label="Particle C", color="b")

plt.plot(Time, Velocity, label="Particle A", color="r")
#plt.plot(B_velocity[:,0], B_velocity[:,1], label="Particle B", color="g")
#plt.plot(C_velocity[:,0], C_velocity[:,1], label="Particle C", color="b")

# Plot the initial triangle
#plt.plot([A_trajectory[0,0], B_trajectory[0,0]], [A_trajectory[0,1], B_trajectory[0,1]], 'k--')
#plt.plot([B_trajectory[0,0], C_trajectory[0,0]], [B_trajectory[0,1], C_trajectory[0,1]], 'k--')
#plt.plot([C_trajectory[0,0], A_trajectory[0,0]], [C_trajectory[0,1], A_trajectory[0,1]], 'k--')

# Plot settings
plt.xlabel("Time")
plt.ylabel("Velocity")
#plt.title("Trajectories of the Three Particles")
plt.legend(loc='lower right', bbox_to_anchor=(1.3, 0))
plt.grid(True, which='both', linestyle=':', alpha=0.8) 
plt.text(1.3, -0.1, f"Simulation Time: {time:.3f} s", transform=plt.gca().transAxes,
         fontsize=10, verticalalignment='top', horizontalalignment='right')
plt.axis()
plt.savefig('3particle_acc_Vel_time.jpg', format='jpeg', bbox_inches='tight', dpi=1000)
plt.show()
# Out:
# Simulation Time: 1.9000000000000015

# %% [markdown]
# # Particles on an equilateral triangle (Limited time)
# Moving with uniform acceleration *a* towards each other at each step (intially at rest), for a limited time.

# %%
# Simulation parameters
d = 0.1  # side length of the triangle
a = 1  # acceleration of the particles
dt = 0.01  # time step
time_steps = 2000 # number of time steps to simulate

# Initial positions of the particles as NumPy arrays
A_pos = np.array([0, 0])
B_pos = np.array([d, 0])
C_pos = np.array([d/2, np.sqrt(3)*d/2])

# Initial positions of the particles as NumPy arrays
A_vel = np.array([0,0])
B_vel = np.array([0,0])
C_vel = np.array([0,0])

time = 0

# Store trajectories for plotting
A_trajectory = [A_pos]
B_trajectory = [B_pos]
C_trajectory = [C_pos]


# Function to calculate the velocity at each step
def update_velocity(x1, y1, x2, y2, vx, vy, a, dt):
    # Calculate the direction towards the target
    direction_x = x2 - x1
    direction_y = y2 - y1
    distance = np.sqrt(direction_x**2 + direction_y**2)
    
    # Update velocity
    new_vx = vx + a * (direction_x / distance) * dt
    new_vy = vy + a * (direction_y / distance) * dt
    return new_vx, new_vy

# Function to calculate the next position
def update_position(x, y, vx, vy, a, dt):
    # Update position
    new_x = x + vx * dt
    new_y = y + vy * dt
    return new_x, new_y

# Function to check if the points are approximately equal
def are_points_equal(p1, p2, p3, tolerance):
    # Compare the differences with a tolerance
    return (abs(p1[0] - p2[0]) <= tolerance and abs(p1[1] - p2[1]) <= tolerance and
            abs(p1[0] - p3[0]) <= tolerance and abs(p1[1] - p3[1]) <= tolerance)


# Run the simulation
for _ in range(time_steps) :

    # Update velocities based on their respective directions
    A_vel = np.array(update_velocity(A_pos[0], A_pos[1], B_pos[0], B_pos[1], A_vel[0], A_vel[1], a, dt))
    B_vel = np.array(update_velocity(B_pos[0], B_pos[1], C_pos[0], C_pos[1], B_vel[0], B_vel[1], a, dt))
    C_vel = np.array(update_velocity(C_pos[0], C_pos[1], A_pos[0], A_pos[1], C_vel[0], C_vel[1], a, dt))
    
    # Update positions based on their respective directions
    A_pos = np.array(update_position(A_pos[0], A_pos[1], A_vel[0], A_vel[1], a, dt))
    B_pos = np.array(update_position(B_pos[0], B_pos[1], B_vel[0], B_vel[1], a, dt))
    C_pos = np.array(update_position(C_pos[0], C_pos[1], C_vel[0], C_vel[1], a, dt))
    
    # Store positions for trajectory
    A_trajectory.append(A_pos)
    B_trajectory.append(B_pos)
    C_trajectory.append(C_pos)


    time = time + dt # update time

    
    if are_points_equal(A_pos, B_pos, C_pos, 1e-2):
        break

    if abs(time - np.sqrt((4*d)/(3*a))) <= 1e-2:
        break
        
print("Simulation Time:", time)

# Convert to numpy arrays for easier plotting
A_trajectory = np.array(A_trajectory)
B_trajectory = np.array(B_trajectory)
C_trajectory = np.array(C_trajectory)

# Plotting the trajectories
plt.figure(figsize=(7,7))
plt.plot(A_trajectory[:,0], A_trajectory[:,1], label="Particle A", color="r")
plt.plot(B_trajectory[:,0], B_trajectory[:,1], label="Particle B", color="g")
plt.plot(C_trajectory[:,0], C_trajectory[:,1], label="Particle C", color="b")


# Plot the initial triangle
plt.plot([A_trajectory[0,0], B_trajectory[0,0]], [A_trajectory[0,1], B_trajectory[0,1]], 'k--')
plt.plot([B_trajectory[0,0], C_trajectory[0,0]], [B_trajectory[0,1], C_trajectory[0,1]], 'k--')
plt.plot([C_trajectory[0,0], A_trajectory[0,0]], [C_trajectory[0,1], A_trajectory[0,1]], 'k--')

# Plot settings
plt.xlabel("X Position")
plt.ylabel("Y Position")
#plt.title("Trajectories of the Three Particles")
plt.legend(loc='lower right', bbox_to_anchor=(1.3, 0))
plt.grid(True, which='both', linestyle=':', alpha=0.8) 
plt.text(1.3, -0.1, f"Simulation Time: {time:.3f} s", transform=plt.gca().transAxes,
         fontsize=10, verticalalignment='top', horizontalalignment='right')
plt.axis()
plt.savefig('3particle_acc_lim.jpg', format='jpeg', bbox_inches='tight', dpi=1000)
plt.show()
# Out:
# Simulation Time: 0.36000000000000015

# %% [markdown]
# # Test

# %%
# Simulation parameters
d = 0.1  # side length of the triangle
a = 1 # acceleration of the particles
dt = 0.01  # time step
time_steps = 2000 # number of time steps to simulate

# Initial positions of the particles as NumPy arrays
A_pos = np.array([0, 0])
B_pos = np.array([d, 0])
C_pos = np.array([d/2, np.sqrt(3)*d/2])

# Initial positions of the particles as NumPy arrays
A_vel = np.array([0,0])
B_vel = np.array([0,0])
C_vel = np.array([0,0])

time = 0

# Store trajectories for plotting
A_trajectory = [A_pos]
B_trajectory = [B_pos]
C_trajectory = [C_pos]

A_velocity = [A_vel]
C_velocity = [C_vel]

Time = [0]
C_velocity = [0]
A_velocity = [0]

# Function to calculate the velocity at each step
def update_velocity(x1, y1, x2, y2, vx, vy, a, dt):
    # Calculate the direction towards the target
    direction_x = x2 - x1
    direction_y = y2 - y1
    distance = np.sqrt(direction_x**2 + direction_y**2)
    
    # Update velocity
    new_vx = vx + a * (direction_x / distance) * dt
    new_vy = vy + a * (direction_y / distance) * dt
    return new_vx, new_vy

# Function to calculate the next position
def update_position(x, y, vx, vy, a, dt):
    # Update position
    new_x = x + vx * dt
    new_y = y + vy * dt
    return new_x, new_y

# Function to check if the points are approximately equal
def are_points_equal(p1, p2, p3, tolerance):
    # Compare the differences with a tolerance
    return (abs(p1[0] - p2[0]) <= tolerance and abs(p1[1] - p2[1]) <= tolerance and
            abs(p1[0] - p3[0]) <= tolerance and abs(p1[1] - p3[1]) <= tolerance)


# Run the simulation
for _ in range(time_steps) :

    # Update velocities based on their respective directions
    A_vel = np.array(update_velocity(A_pos[0], A_pos[1], B_pos[0], B_pos[1], A_vel[0], A_vel[1], a, dt))
    B_vel = np.array(update_velocity(B_pos[0], B_pos[1], C_pos[0], C_pos[1], B_vel[0], B_vel[1], a, dt))
    C_vel = np.array(update_velocity(C_pos[0], C_pos[1], A_pos[0], A_pos[1], C_vel[0], C_vel[1], a, dt))
    
    # Update positions based on their respective directions
    A_pos = np.array(update_position(A_pos[0], A_pos[1], A_vel[0], A_vel[1], a, dt))
    B_pos = np.array(update_position(B_pos[0], B_pos[1], B_vel[0], B_vel[1], a, dt))
    C_pos = np.array(update_position(C_pos[0], C_pos[1], C_vel[0], C_vel[1], a, dt))
    
    # Store positions for trajectory
    A_trajectory.append(A_pos)
    B_trajectory.append(B_pos)
    C_trajectory.append(C_pos)


    time = time + dt
    Time.append(time)
    A_velocity.append(np.sqrt((A_vel[0])**2 + (A_vel[1])**2))
    C_velocity.append(np.sqrt((C_vel[0])**2 + (C_vel[1])**2))
    
    if are_points_equal(A_pos, B_pos, C_pos, 1e-2):
        break

    if abs(time - np.sqrt((4*d)/(3*a))) <= 1e-2:
        break
        
print("Simulation Time:", time)
print(len(Time))

# Convert to numpy arrays for easier plotting
A_trajectory = np.array(A_trajectory)
B_trajectory = np.array(B_trajectory)
C_trajectory = np.array(C_trajectory)


# Plotting the trajectories
plt.figure(figsize=(7,7))
plt.plot(Time,A_velocity, label="Particle A", color="r")
plt.xlabel("Time")
plt.ylabel("A Velocity")
#plt.title("Trajectories of the Three Particles")
plt.legend(loc='lower right', bbox_to_anchor=(1.3, 0))
plt.grid(True, which='both', linestyle=':', alpha=0.8) 
plt.text(1.3, -0.1, f"Simulation Time: {time:.3f} s", transform=plt.gca().transAxes,
         fontsize=10, verticalalignment='top', horizontalalignment='right')
plt.axis()
plt.savefig('A_velocity_time.jpg', format='jpeg', bbox_inches='tight', dpi=1000)
plt.show()

plt.figure(figsize=(7,7))
plt.plot(Time,C_velocity, label="Particle C", color="b")
# Plot settings
plt.xlabel("Time")
plt.ylabel("C Velocity")
#plt.title("Trajectories of the Three Particles")
plt.legend(loc='lower right', bbox_to_anchor=(1.3, 0))
plt.grid(True, which='both', linestyle=':', alpha=0.8) 
plt.text(1.3, -0.1, f"Simulation Time: {time:.3f} s", transform=plt.gca().transAxes,
         fontsize=10, verticalalignment='top', horizontalalignment='right')
plt.axis()
plt.savefig('C_velocity_time.jpg', format='jpeg', bbox_inches='tight', dpi=1000)
plt.show()
# Out:
# Simulation Time: 0.36000000000000015
# 37

# %%
def simpsons_rule(time, velocity):
    # Ensure the number of intervals is even
    if len(time) < 3 or len(time) % 2 == 0:
        raise ValueError("Simpson's rule requires an odd number of data points (even number of intervals).")
    
    n = len(time) - 1  # Number of intervals
    delta_t = time[1] - time[0]  # Assuming equal spacing

    # Apply Simpson's Rule: S = (Δt / 3) * [v0 + 4v1 + 2v2 + 4v3 + ... + vn]
    S = velocity[0] + velocity[-1]  # Start with v0 and vn
    
    for i in range(1, n):
        if i % 2 == 0:  # Even index
            S += 2 * velocity[i]
        else:  # Odd index
            S += 4 * velocity[i]

    # Final distance calculation
    distance = (delta_t / 3) * S
    
    return distance


distance1 = simpsons_rule(Time, A_velocity)
print(f"Distance covered by A: {distance1:.4f} meters")

distance2 = simpsons_rule(Time, C_velocity)
print(f"Distance covered by C: {distance2:.4f} meters")

total_distance = distance1 + distance2
print(f"Total Distance Covered by both: {total_distance:.4f} meters")
# Out:
# Distance covered by A: 0.0635 meters
# Distance covered by C: 0.0635 meters
# Total Distance Covered by both: 0.1270 meters
